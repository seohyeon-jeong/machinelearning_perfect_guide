# %% [markdown]
# ## *colab과 google Drive 연동을 위한 인증 및 네트워크 디렉토리 마운트*

# %%
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### 연동 후 자신의 google drive에 있는 data directory 확인

# %%
# !cd "/content/drive/My Drive/data";

# %% [markdown]
# - 기타 환경 정보 확인

# %%
# cat : concatenate 파일이름을 인자로 받아서 그 내용을 쭉 이어주는 역할 
# cat [옵션] [파일명]
# !cat /proc/meminfo;cat / proc/cpuinfo
# Out:
# MemTotal:       13333596 kB
# MemFree:        10762844 kB
# MemAvailable:   12506840 kB
# Buffers:           81088 kB
# Cached:          1814296 kB
# SwapCached:            0 kB
# Active:           649196 kB
# Inactive:        1656664 kB
# Active(anon):     383212 kB
# Inactive(anon):      336 kB
# Active(file):     265984 kB
# Inactive(file):  1656328 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               560 kB
# Writeback:             0 kB
# AnonPages:        410544 kB
# Mapped:           238244 kB
# Shmem:               936 kB
# Slab:             163412 kB
# SReclaimable:     125000 kB
# SUnreclaim:        38412 kB
# KernelStack:        4432 kB
# PageTables:         5956 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6666796 kB
# Committed_AS:    2953020 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# VmallocChunk:          0 kB
# Percpu:              952 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:       83176 kB
# DirectMap2M:     4110336 kB
# DirectMap1G:    11534336 kB
# cat: /: Is a directory
# cat: proc/cpuinfo: No such file or directory
